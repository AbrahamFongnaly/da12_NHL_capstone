# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

# %%
# Define the path to your CSV files
path = 'C:\DA12\capstone\da12_NHL_capstone\data'

# Get a list of all CSV files in the directory
csv_files = glob.glob(os.path.join(path, "*.csv"))

# Create an empty list to store DataFrames
dfs = []

# Loop over the list of CSV files and read each file
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)

# Combine all DataFrames into one (optional)
nhl_goalie_df = pd.concat(dfs, ignore_index=True)

# Display the first few rows of the combined DataFrame
print(f"Loaded {len(dfs)} CSV files.")
nhl_goalie_df
# Out:
# Loaded 16 CSV files.
#       playerId  season             name team position situation  games_played  \
# 0      8470140    2008    Kari Lehtonen  ATL        G     other            46
# 1      8470140    2008    Kari Lehtonen  ATL        G       all            46
# 2      8470140    2008    Kari Lehtonen  ATL        G      5on5            46
# 3      8470140    2008    Kari Lehtonen  ATL        G      4on5            46
# 4      8470140    2008    Kari Lehtonen  ATL        G      5on4            46
# ...        ...     ...              ...  ...      ...       ...           ...
# 7500   8482821    2023  Arvid Soderblom  CHI        G     other            32
# 7501   8482821    2023  Arvid Soderblom  CHI        G       all            32
# 7502   8482821    2023  Arvid Soderblom  CHI        G      5on5            32
# 7503   8482821    2023  Arvid Soderblom  CHI        G      4on5            32
# 7504   8482821    2023  Arvid Soderblom  CHI        G      5on4            32
#
# ...

# %%
nhl_teams_data = pd.read_csv(r"C:\DA12\capstone\da12_NHL_capstone\extradata\all_teams.csv")
nhl_teams_data
# Out:
#        team  season name      gameId playerTeam opposingTeam home_or_away  \
# 0       NYR    2008  NYR  2008020001        NYR          T.B         AWAY
# 1       NYR    2008  NYR  2008020001        NYR          T.B         AWAY
# 2       NYR    2008  NYR  2008020001        NYR          T.B         AWAY
# 3       NYR    2008  NYR  2008020001        NYR          T.B         AWAY
# 4       NYR    2008  NYR  2008020001        NYR          T.B         AWAY
# ...     ...     ...  ...         ...        ...          ...          ...
# 204295  L.A    2017  L.A  2017030174        L.A          VGK         HOME
# 204296  L.A    2017  L.A  2017030174        L.A          VGK         HOME
# 204297  L.A    2017  L.A  2017030174        L.A          VGK         HOME
# 204298  L.A    2017  L.A  2017030174        L.A          VGK         HOME
# 204299  L.A    2017  L.A  2017030174        L.A          VGK         HOME
#
#         gameDate    position situation  ...  unblockedShotAttemptsAgainst  \
# ...
